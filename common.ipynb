# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("final.xlsx")

# %%
data = data[(data['DEMO_Org'] != 'Org 5') & (data['DEMO_Org'] != 'Org 2')]

# %%
pd.set_option('display.max_columns', None) 

pd.set_option('display.max_rows', None)

data.shape
# Out:
# (713, 186)

# %%
data.head()
# Out:
#     Unnamed: 0 DEMO_Org DEMO_meeting_remote   DEMO_Dept  \
# 4            4    Org 3                  No  Accounting
# 5            5    Org 3                  No  Accounting
# 8            8    Org 3                  No  Accounting
# 9            9    Org 3                 Yes  Accounting
# 10          10    Org 3                  No  Accounting
#
#     OBSV_PreC_Location_A_primryoffice  OBSV_PreC_Location_B_officeother  \
# 4                                 NaN                               NaN
# 5                                 NaN                               NaN
# 8                                 NaN                               NaN
# 9                                 NaN                               NaN
# 10                                NaN                               NaN
#
#     OBSV_PreC_Location_C_client  OBSV_PreC_Location_D_WFH  \
# 4                           NaN                       NaN
# 5                           NaN                       NaN
# 8                           NaN                       NaN
# 9                           NaN                       NaN
# 10                          NaN                       NaN
#
#     OBSV_PreC_Location_E_publicspace  OBSV_PreC_Location_F_transit  \
# 4                                NaN                           NaN
# 5                                NaN                           NaN
# 8                                NaN                           NaN
# 9                                NaN                           NaN
# 10                               NaN                           NaN
#
#     OBSV_PreC_Location_G_other  OBSV_Now_Interact_Work_within_org  \
# 4                          NaN                                0.0
# 5                          NaN                                0.0
# 8                          NaN                                0.0
# 9                          NaN                                0.0
# 10                         NaN                                0.0
#
#     OBSV_PreC_meeting_A_inperson  OBSV_PreC_meeting_B_hyrbid  \
# 4                            0.0                         1.0
# 5                            0.6                         0.3
# 8                            0.2                         0.8
# 9                            0.7                         0.2
# 10                           0.5                         0.5
#
#     OBSV_PreC_meeting_C_remote  OBSV_PreC_interative_A_inperson  \
# 4                          0.0                              NaN
# 5                          0.1                              NaN
# 8                          0.0                              NaN
# 9                          0.1                              NaN
# 10                         0.0                              NaN
#
#     OBSV_PreC_interative_B_remote  OBSV_same_space_count_A_1  \
# 4                             NaN                        NaN
# 5                             NaN                        NaN
# 8                             NaN                        NaN
# 9                             NaN                        NaN
# 10                            NaN                        NaN
#
#     OBSV_same_space_count_B_2n3  OBSV_same_space_count_C_4n9  \
# 4                           NaN                          NaN
# 5                           NaN                          NaN
# 8                           NaN                          NaN
# 9                           NaN                          NaN
# 10                          NaN                          NaN
#
#     OBSV_same_space_count_D_10p  OBSV_PreC_meetingsize0ffice_A_1  \
# 4                           NaN                         1.000000
# 5                           NaN                         0.200000
# 8                           NaN                         0.200000
# 9                           NaN                         0.526316
# 10                          NaN                         0.000000
#
#     OBSV_PreC_meetingsize0ffice_B_2n3  OBSV_PreC_meetingsize0ffice_C_4n9  \
# 4                            0.000000                           0.000000
# 5                            0.400000                           0.200000
# 8                            0.100000                           0.700000
# 9                            0.105263                           0.368421
# 10                           0.000000                           1.000000
#
#     OBSV_PreC_wiOffice_A_desk  OBSV_PreC_wiOffice_B_otherdeck  \
# 4                        1.00                           0.000
# 5                        1.00                           0.000
# 8                        1.00                           0.000
# 9                        0.80                           0.125
# 10                       0.95                           0.000
#
#     OBSV_PreC_wiOffice_C_meetingrm  OBSV_PreC_wiOffice_D_lobby  \
# 4                            0.000                        0.00
# 5                            0.000                        0.00
# 8                            0.000                        0.00
# 9                            0.075                        0.00
# 10                           0.000                        0.05
#
#     OBSV_PreC_wiOffice_E_speicaltyarea  OBSV_PreC_wiOffice_F_other  \
# 4                                  0.0                0.000000e+00
# 5                                  0.0                0.000000e+00
# 8                                  0.0                0.000000e+00
# 9                                  0.0                1.110223e-16
# 10                                 0.0                0.000000e+00
#
#    OBSV_PreC_space_A_InformalMtg OBSV_PreC_space_B_FormalMtg  \
# 4               your desk/office                meeting room
# 5               your desk/office                meeting room
# 8                   meeting room                meeting room
# 9                   meeting room                meeting room
# 10              your desk/office                meeting room
#
#     OBSV_PreC_5A_lost_layout  OBSV_PreC_5B_lost_looking  \
# 4                        0.0                       20.0
# 5                       50.0                      300.0
# 8                       60.0                       10.0
# 9                        0.0                       10.0
# 10                       0.0                      200.0
#
#     OBSV_PreC_5C_lost_perstech  OBSV_PreC_5D_lost_roomtech  \
# 4                          0.0                         0.0
# 5                         50.0                        50.0
# 8                          0.0                        10.0
# 9                          0.0                         5.0
# 10                        50.0                       100.0
#
#     OBSV_PreC_5E_lost_visitors  OBSV_PreC_5F_lost_noise  \
# 4                          0.0                      0.0
# 5                        150.0                    400.0
# 8                         30.0                     45.0
# 9                          0.0                      0.0
# 10                      1350.0                     50.0
#
#     OBSV_PreC_5G_lost_comms  OBSV_PreC_5H_lost_ergo  OBSV_PreC_5I_lost_temp  \
# 4                       0.0                     0.0                     0.0
# 5                     300.0                   300.0                   300.0
# 8                      20.0                     0.0                    10.0
# 9                      10.0                     0.0                     0.0
# 10                    650.0                     0.0                     0.0
#
#     OBSV_PreC_5J_lost_odor  OBSV_PreC_5K_lost_natlight  \
# 4                      0.0                         0.0
# 5                    350.0                        50.0
# 8                      0.0                         NaN
# 9                      0.0                         5.0
# 10                     0.0                         0.0
#
#     OBSV_PreC_5L_lost_indoorlight  PostC_impact_RankDifficult_A_MH  \
# 4                             0.0                              2.0
# 5                           100.0                              4.0
# 8                             NaN                              1.0
# 9                             5.0                              5.0
# 10                            0.0                              1.0
#
#     PostC_impact_RankDifficult_B_community  \
# 4                                      5.0
# 5                                      1.0
# 8                                      5.0
# 9                                      3.0
# 10                                     3.0
#
#     PostC_impact_RankDifficult_C_Communication  \
# 4                                          4.0
# 5                                          3.0
# 8                                          4.0
# 9                                          1.0
# 10                                         4.0
#
#     PostC_impact_RankDifficult_D_Tech  PostC_impact_RankDifficult_E_space  \
# 4                                 0.0                                 1.0
# 5                                 5.0                                 0.0
# 8                                 2.0                                 0.0
# 9                                 0.0                                 4.0
# 10                                2.0                                 0.0
#
#     PostC_impact_RankDifficult_F_Environment  PostC_impact_shift_D_videoconf  \
# 4                                        3.0                             NaN
# 5                                        2.0                             NaN
# 8                                        3.0                             NaN
# 9                                        2.0                             NaN
# 10                                       5.0                             NaN
#
#     PostC_impact_shift_E_innovate  DECSN_factors_E_commutelength  \
# 4                             2.5                            1.0
# 5                             4.0                            0.0
# 8                             2.5                            4.0
# 9                             4.0                            0.0
# 10                            0.0                            1.0
#
#     DECSN_factors_F_collabtools  DECSN_factors_G_concentrate  \
# 4                           4.0                          5.0
# 5                           NaN                          NaN
# 8                           2.5                          4.0
# 9                           4.0                          5.0
# 10                          0.0                          4.0
#
#     DECSN_factors_H_purpose  DECSN_factors_I_coworkerspresence  \
# 4                       4.0                                NaN
# 5                       NaN                                NaN
# 8                       5.0                                NaN
# 9                       5.0                                NaN
# 10                      2.5                                NaN
#
#     DECSN_factors_J_teampresence  DECSN_factors_K_socialevents  \
# 4                            4.0                           1.0
# 5                            NaN                           NaN
# 8                            2.5                           0.0
# 9                            1.0                           4.0
# 10                           0.0                           1.0
#
#     DECSN_factors_L_community  DECSN_factors_M_metorship  \
# 4                         2.5                        2.5
# 5                         NaN                        NaN
# 8                         0.0                        0.0
# 9                         2.5                        1.0
# 10                        2.5                        0.0
#
#     DECSN_factors_N_neighorhood  DECSN_factors_O_food  DECSN_factors_P_family  \
# 4                           2.5                   1.0                     5.0
# 5                           NaN                   NaN                     NaN
# 8                           0.0                   0.0                     1.0
# 9                           0.0                   0.0                     1.0
# 10                          0.0                   0.0                     1.0
#
#     DECSN_factors_Q_leadership  PREF_space_A_focusedWk  \
# 4                          5.0                     0.0
# 5                          NaN                     0.0
# 8                          5.0                     1.0
# 9                          2.5                     0.0
# 10                         1.0                     1.0
#
#     PREF_Envr_Focus_1A_activity  PREF_Envr_Focus_1B_closure  \
# 4                           1.0                        10.0
# 5                           1.0                         1.0
# 8                           0.0                         0.0
# 9                           1.0                         1.0
# 10                          1.0                         1.0
#
#     PREF_Envr_Focus_1C_remote  PREF_Envr_Focus_1D_color  \
# 4                         9.0                       8.0
# 5                         5.0                       1.0
# 8                         0.0                       0.0
# 9                         1.0                       8.0
# 10                        1.0                       1.0
#
#     PREF_Envr_Focus_1E_light  PREF_Envr_Focus_1F_formality  \
# 4                       10.0                           5.0
# 5                        1.0                           1.0
# 8                        1.0                           0.0
# 9                        8.0                           8.0
# 10                       1.0                           5.0
#
#     PREF_Envr_Focus_1H_energy  PREF_Envr_Collab_2A_activity  \
# 4                        10.0                           4.0
# 5                         1.0                           1.0
# 8                         NaN                           5.0
# 9                         4.0                           1.0
# 10                        1.0                           1.0
#
#     PREF_Envr_Collab_2B_closure  PREF_Envr_Collab_2C_remote  \
# 4                           9.0                         6.0
# 5                          10.0                         1.0
# 8                           7.0                         5.0
# 9                           5.0                         4.0
# 10                          1.0                         1.0
#
#     PREF_Envr_Collab_2D_color  PREF_Envr_Collab_2E_light  \
# 4                         9.0                       10.0
# 5                        10.0                        1.0
# 8                         7.0                        6.0
# 9                         8.0                        8.0
# 10                        1.0                        1.0
#
#     PREF_Envr_Collab_2F_formality  PREF_Envr_Collab_2H_energy  \
# 4                             6.0                        10.0
# 5                             1.0                        10.0
# 8                             6.0                         8.0
# 9                             5.0                         4.0
# 10                            1.0                         1.0
#
#    PREF_features_A_chair PREF_features_B_proximitry  \
# 4              Important                  Important
# 5            Unimportant                    Neutral
# 8         Very important                  Important
# 9              Important                Unimportant
# 10               Neutral                  Important
#
#    PREF_features_C_concentration PREF_features_D_privacy  \
# 4               Very unimportant               Important
# 5               Very unimportant                 Neutral
# 8               Very unimportant               Important
# 9               Very unimportant               Important
# 10              Very unimportant                 Neutral
#
#    PREF_features_E_noise PREF_features_F_daylight PREF_features_G_light  \
# 4              Important                Important             Important
# 5              Important                Important               Neutral
# 8         Very important                Important             Important
# 9         Very important           Very important             Important
# 10             Important              Unimportant      Very unimportant
#
#    PREF_features_H_nature PREF_features_I_Sychro PREF_features_J_collabspace  \
# 4               Important                    NaN                         NaN
# 5               Important                    NaN                         NaN
# 8                 Neutral                    NaN                         NaN
# 9               Important                    NaN                         NaN
# 10       Very unimportant                    NaN                         NaN
#
#    PREF_features_K_temp PREF_features_L_clean PREF_features_M_lockers  \
# 4             Important             Important        Very unimportant
# 5             Important        Very important        Very unimportant
# 8             Important        Very important        Very unimportant
# 9           Unimportant        Very important        Very unimportant
# 10     Very unimportant               Neutral        Very unimportant
#
#    PREF_features_N_events PREF_features_O_food  PREF_features_Q_kitchen  \
# 4        Very unimportant     Very unimportant                      NaN
# 5        Very unimportant     Very unimportant                      NaN
# 8        Very unimportant     Very unimportant                      NaN
# 9        Very unimportant     Very unimportant                      NaN
# 10       Very unimportant     Very unimportant                      NaN
#
#    PREF_features_R_gym PREF_features_S_relax PREF_features_T_greenspace  \
# 4     Very unimportant      Very unimportant           Very unimportant
# 5     Very unimportant      Very unimportant           Very unimportant
# 8     Very unimportant      Very unimportant           Very unimportant
# 9     Very unimportant      Very unimportant           Very unimportant
# 10    Very unimportant      Very unimportant           Very unimportant
#
#     PREF_CollabSpace_A_tech  PREF_CollabSpace_B_software  \
# 4                       5.0                          5.0
# 5                       5.0                          5.0
# 8                       4.0                          4.0
# 9                       4.0                          4.0
# 10                      1.0                          4.0
#
#     PREF_CollabSpace_C_CollabTools  PREF_CollabSpace_D_furniture  \
# 4                              4.0                           5.0
# 5                              5.0                           3.0
# 8                              1.0                           4.0
# 9                              4.0                           4.0
# 10                             3.0                           3.0
#
#     PREF_CollabSpace_E_seating  PREF_CollabSpace_F_naturallight  \
# 4                          5.0                              5.0
# 5                          3.0                              4.0
# 8                          2.0                              4.0
# 9                          4.0                              5.0
# 10                         3.0                              3.0
#
#     PREF_CollabSpace_G_acoustics  SATSF_CollabSpace_A_Tech  \
# 4                            4.0                       5.0
# 5                            4.0                       5.0
# 8                            3.0                       5.0
# 9                            4.0                       5.0
# 10                           3.0                       4.0
#
#     SATSF_CollabSpace_B_software  SATSF_CollabSpace_C_CollabTools  \
# 4                            5.0                              5.0
# 5                            5.0                              5.0
# 8                            5.0                              3.0
# 9                            4.0                              4.0
# 10                           4.0                              4.0
#
#     SATSF_CollabSpace_D_furniture  SATSF_CollabSpace_E_seating  \
# 4                             5.0                          5.0
# 5                             4.0                          4.0
# 8                             4.0                          4.0
# 9                             4.0                          4.0
# 10                            4.0                          4.0
#
#     SATSF_CollabSpace_F_naturallight  SATSF_CollabSpace_G_acoustics  \
# 4                                5.0                            5.0
# 5                                4.0                            4.0
# 8                                5.0                            4.0
# 9                                2.0                            4.0
# 10                               4.0                            3.0
#
#     SATSF_HomeOffice_A_Tech  SATSF_HomeOffice_B_software  \
# 4                       5.0                          5.0
# 5                       5.0                          5.0
# 8                       5.0                          5.0
# 9                       2.0                          4.0
# 10                      5.0                          5.0
#
#     SATSF_HomeOffice_C_CollabTools  SATSF_HomeOffice_D_furniture  \
# 4                              4.0                           5.0
# 5                              5.0                           3.0
# 8                              3.0                           4.0
# 9                              4.0                           2.0
# 10                             5.0                           5.0
#
#     SATSF_HomeOffice_E_seating  SATSF_HomeOffice_F_naturallight  \
# 4                          5.0                              5.0
# 5                          3.0                              4.0
# 8                          4.0                              5.0
# 9                          3.0                              5.0
# 10                         5.0                              5.0
#
#     SATSF_HomeOffice_G_acoustics  SATSF_office_A_community  \
# 4                            5.0                       5.0
# 5                            4.0                       4.0
# 8                            4.0                       5.0
# 9                            4.0                       4.0
# 10                           3.0                       3.0
#
#     SATSF_office_B_designexcellence  SATSF_office_C_pride  \
# 4                               4.0                   5.0
# 5                               4.0                   4.0
# 8                               5.0                   5.0
# 9                               4.0                   4.0
# 10                              3.0                   5.0
#
#     SATSF_office_D_expressme  SATSF_office_E_control  \
# 4                        5.0                     5.0
# 5                        3.0                     3.0
# 8                        5.0                     3.0
# 9                        4.0                     3.0
# 10                       5.0                     5.0
#
#     SATSF_office_F_wellbeing  SATSF_office_G_myfamily  \
# 4                        5.0                      5.0
# 5                        4.0                      4.0
# 8                        5.0                      5.0
# 9                        4.0                      3.0
# 10                       5.0                      4.0
#
#     SATSF_office_H_customers  SATSF_office_I_orgcullture  \
# 4                        5.0                         4.0
# 5                        4.0                         4.0
# 8                        5.0                         5.0
# 9                        4.0                         4.0
# 10                       3.0                         3.0
#
#     SATSF_office_J_knowledgeshare  SATSF_office_K_planet  \
# 4                             5.0                    4.0
# 5                             3.0                    3.0
# 8                             5.0                    5.0
# 9                             4.0                    4.0
# 10                            3.0                    3.0
#
#     SATSF_facilitate_Home_1A_focus  SATSF_facilitate_Home_1B_inpersoncollab  \
# 4                              5.0                                      5.0
# 5                              3.0                                      3.0
# 8                              5.0                                      3.0
# 9                              4.0                                      3.0
# 10                             5.0                                      5.0
#
#     SATSF_facilitate_Home_1C_virtualcollab  SATSF_facilitate_Office_2A_focus  \
# 4                                      5.0                               5.0
# 5                                      3.0                               4.0
# 8                                      5.0                               3.0
# 9                                      4.0                               4.0
# 10                                     5.0                               3.0
#
#     SATSF_facilitate_Office_2B_inpersoncollab  \
# 4                                         5.0
# 5                                         4.0
# 8                                         5.0
# 9                                         4.0
# 10                                        4.0
#
#     SATSF_facilitate_Office_2C_virtualcollab  \
# 4                                        5.0
# 5                                        4.0
# 8                                        3.0
# 9                                        4.0
# 10                                       3.0
#
#     SATSF_facilitate_HomeTech_3A_virtualcollab  \
# 4                                          5.0
# 5                                          2.0
# 8                                          5.0
# 9                                          4.0
# 10                                         5.0
#
#     SATSF_facilitate_HomeTech_3B_inpersoncollab  \
# 4                                           5.0
# 5                                           2.0
# 8                                           3.0
# 9                                           3.0
# 10                                          5.0
#
#     SATSF_facilitate_HomeTech_3C_virtualcollab  \
# 4                                          5.0
# 5                                          2.0
# 8                                          5.0
# 9                                          4.0
# 10                                         5.0
#
#     SATSF_facilitate_OfficeTech_4A_virtualcollab  \
# 4                                            5.0
# 5                                            4.0
# 8                                            3.0
# 9                                            4.0
# 10                                           4.0
#
#     SATSF_facilitate_OfficeTech_4B_inpersoncollab  \
# 4                                             5.0
# 5                                             4.0
# 8                                             5.0
# 9                                             4.0
# 10                                            4.0
#
#     SATSF_facilitate_OfficeTech_4C_virtualcollab  WP_Featr_office_A_community  \
# 4                                            5.0                          3.0
# 5                                            4.0                          3.0
# 8                                            3.0                          4.0
# 9                                            4.0                          3.0
# 10                                           4.0                          3.0
#
#     WP_Featr_office_B_designexcellence  WP_Featr_office_C_pride  \
# 4                                  4.0                      5.0
# 5                                  1.0                      3.0
# 8                                  3.0                      5.0
# 9                                  4.0                      4.0
# 10                                 3.0                      5.0
#
#     WP_Featr_office_D_expressme  WP_Featr_office_E_control  \
# 4                           3.0                        4.0
# 5                           2.0                        3.0
# 8                           5.0                        2.0
# 9                           2.0                        3.0
# 10                          4.0                        4.0
#
#     WP_Featr_office_F_wellbeing  WP_Featr_office_G_myfamily  \
# 4                           5.0                         5.0
# 5                           4.0                         4.0
# 8                           4.0                         4.0
# 9                           4.0                         4.0
# 10                          4.0                         4.0
#
#     WP_Featr_office_H_customers  WP_Featr_office_I_oegculture  \
# 4                           4.0                           4.0
# 5                           3.0                           2.0
# 8                           3.0                           3.0
# 9                           4.0                           4.0
# 10                          3.0                           3.0
#
#     WP_Featr_office_J_knowledgeshare  WP_Featr_office_K_planet  \
# 4                                5.0                       5.0
# 5                                3.0                       3.0
# 8                                3.0                       3.0
# 9                                5.0                       3.0
# 10                               3.0                       3.0
#
#     Etc1_WLB_improved  Etc2_chooseWFH  Etc3_no_workstation  Etc4_justlaptop  \
# 4                 3.0             4.0                  2.0              1.0
# 5                 3.0             2.0                  3.0              5.0
# 8                 5.0             5.0                  4.0              1.0
# 9                 3.0             4.0                  4.0              2.0
# 10                5.0             4.0                  3.0              4.0
#
#     Etc5_teamclose  Etc6_connected  Etc7_priorities  Etc8_WFK_efffective  \
# 4              1.0             3.0              5.0                  5.0
# 5              3.0             2.0              3.0                  3.0
# 8              2.0             2.0              5.0                  5.0
# 9              2.0             1.0              5.0                  4.0
# 10             2.0             3.0              5.0                  5.0
#
#     OBSV_PreC_WFH_Days_Wk DEMO_Tenure_PreC_employee  PREF_WFK_rate_home  \
# 4                     5.0                       NaN                 1.0
# 5                     0.0                       NaN                 0.4
# 8                     0.0                       NaN                 0.6
# 9                     1.0                       NaN                 0.1
# 10                    0.0                       NaN                 0.6
#
#     PostC_impact_shift_A_focus  PostC_impact_shift_B_productive  \
# 4                          1.0                              1.0
# 5                          5.0                              5.0
# 8                          0.0                              2.5
# 9                          5.0                              4.0
# 10                         0.0                              0.0
#
#     PostC_impact_shift_C_collab  PostC_impact_shift_F_colleagueaccess  \
# 4                           2.5                                   2.5
# 5                           2.5                                   2.5
# 8                           2.5                                   2.5
# 9                           4.0                                   2.5
# 10                          2.5                                   2.5
#
#     PostC_impact_shift_G_teammeetings  PostC_impact_shift_H_social  \
# 4                                 NaN                          2.5
# 5                                 NaN                          2.5
# 8                                 NaN                          5.0
# 9                                 NaN                          5.0
# 10                                NaN                          2.5
#
#     PostC_impact_shift_I_managersconnect  PostC_impact_shift_J_client  \
# 4                                    2.5                          2.5
# 5                                    2.5                          4.0
# 8                                    4.0                          4.0
# 9                                    5.0                          2.5
# 10                                   2.5                          2.5
#
#     PostC_impact_shift_K_enjoy  DECSN_factors_A_noinpersonmtgs  \
# 4                          2.5                             2.5
# 5                          4.0                             0.0
# 8                          2.5                             4.0
# 9                          5.0                             4.0
# 10                         0.0                             4.0
#
#     DECSN_factors_B_healthwellness  DECSN_factors_C_WrkLifeSep  \
# 4                              5.0                         4.0
# 5                              2.5                         2.5
# 8                              5.0                         4.0
# 9                              4.0                         4.0
# 10                             5.0                         5.0
#
#     DECSN_factors_D_safety  OBSV_Now_WrkTimeA_Indiv_fract_vCollab  \
# 4                      NaN                                    1.0
# 5                      NaN                                    1.0
# 8                      NaN                                    1.0
# 9                      NaN                                    1.0
# 10                     NaN                                    1.0
#
#     OBSV_PreC_meetingsize0ffice_D_10plus  PREF_space_B_inperson_collab  \
# 4                                    0.0                           0.0
# 5                                    0.2                           0.0
# 8                                    0.0                           0.0
# 9                                    0.0                           0.0
# 10                                   0.0                           0.0
#
#     PREF_space_C_videoconf  PREF_space_D_impromptu  PREF_space_E_recharge  \
# 4                      0.0                     0.0                    0.0
# 5                      0.0                     0.0                    1.0
# 8                      1.0                     0.0                    1.0
# 9                      0.0                     1.0                    1.0
# 10                     1.0                     0.0                    1.0
#
#     PREF_space_F_accessible  PREF_space_G_firstarrive
# 4                       0.0                       0.0
# 5                       1.0                       1.0
# 8                       0.0                       1.0
# 9                       0.0                       0.0
# 10                      1.0                       1.0

# %%
sum(data.isna().sum() <= 843/2)
# Out:
# 166

# %%
data.isna().sum()
# Out:
# Unnamed: 0                                         0
# DEMO_Org                                           0
# DEMO_meeting_remote                              243
# DEMO_Dept                                          0
# OBSV_PreC_Location_A_primryoffice                477
# OBSV_PreC_Location_B_officeother                 477
# OBSV_PreC_Location_C_client                      477
# OBSV_PreC_Location_D_WFH                         477
# OBSV_PreC_Location_E_publicspace                 477
# OBSV_PreC_Location_F_transit                     477
# OBSV_PreC_Location_G_other                       477
# OBSV_Now_Interact_Work_within_org                  3
# OBSV_PreC_meeting_A_inperson                     100
# OBSV_PreC_meeting_B_hyrbid                       100
# OBSV_PreC_meeting_C_remote                       100
# OBSV_PreC_interative_A_inperson                  562
# OBSV_PreC_interative_B_remote                    562
# OBSV_same_space_count_A_1                        470
# OBSV_same_space_count_B_2n3                      470
# OBSV_same_space_count_C_4n9                      470
# OBSV_same_space_count_D_10p                      470
# OBSV_PreC_meetingsize0ffice_A_1                  121
# OBSV_PreC_meetingsize0ffice_B_2n3                121
# OBSV_PreC_meetingsize0ffice_C_4n9                121
# OBSV_PreC_wiOffice_A_desk                         96
# OBSV_PreC_wiOffice_B_otherdeck                    96
# OBSV_PreC_wiOffice_C_meetingrm                    96
# OBSV_PreC_wiOffice_D_lobby                        96
# OBSV_PreC_wiOffice_E_speicaltyarea                96
# OBSV_PreC_wiOffice_F_other                        96
# OBSV_PreC_space_A_InformalMtg                    243
# OBSV_PreC_space_B_FormalMtg                      243
# OBSV_PreC_5A_lost_layout                         391
# OBSV_PreC_5B_lost_looking                        308
# OBSV_PreC_5C_lost_perstech                       351
# OBSV_PreC_5D_lost_roomtech                       370
# OBSV_PreC_5E_lost_visitors                       308
# OBSV_PreC_5F_lost_noise                          327
# OBSV_PreC_5G_lost_comms                          319
# OBSV_PreC_5H_lost_ergo                           404
# OBSV_PreC_5I_lost_temp                           378
# OBSV_PreC_5J_lost_odor                           407
# OBSV_PreC_5K_lost_natlight                       405
# OBSV_PreC_5L_lost_indoorlight                    393
# PostC_impact_RankDifficult_A_MH                  248
# PostC_impact_RankDifficult_B_community           248
# PostC_impact_RankDifficult_C_Communication       248
# PostC_impact_RankDifficult_D_Tech                248
# PostC_impact_RankDifficult_E_space               248
# PostC_impact_RankDifficult_F_Environment         248
# PostC_impact_shift_D_videoconf                   471
# PostC_impact_shift_E_innovate                     86
# DECSN_factors_E_commutelength                    328
# DECSN_factors_F_collabtools                      338
# DECSN_factors_G_concentrate                      338
# DECSN_factors_H_purpose                          338
# DECSN_factors_I_coworkerspresence                713
# DECSN_factors_J_teampresence                     337
# DECSN_factors_K_socialevents                     338
# DECSN_factors_L_community                        338
# DECSN_factors_M_metorship                        338
# DECSN_factors_N_neighorhood                      338
# DECSN_factors_O_food                             338
# DECSN_factors_P_family                           338
# DECSN_factors_Q_leadership                       337
# PREF_space_A_focusedWk                             4
# PREF_Envr_Focus_1A_activity                      169
# PREF_Envr_Focus_1B_closure                       150
# PREF_Envr_Focus_1C_remote                        160
# PREF_Envr_Focus_1D_color                          80
# PREF_Envr_Focus_1E_light                          24
# PREF_Envr_Focus_1F_formality                     117
# PREF_Envr_Focus_1H_energy                         66
# PREF_Envr_Collab_2A_activity                      79
# PREF_Envr_Collab_2B_closure                       74
# PREF_Envr_Collab_2C_remote                        74
# PREF_Envr_Collab_2D_color                         54
# PREF_Envr_Collab_2E_light                         14
# PREF_Envr_Collab_2F_formality                     76
# PREF_Envr_Collab_2H_energy                        37
# PREF_features_A_chair                             75
# PREF_features_B_proximitry                       247
# PREF_features_C_concentration                      0
# PREF_features_D_privacy                            4
# PREF_features_E_noise                              4
# PREF_features_F_daylight                           4
# PREF_features_G_light                              4
# PREF_features_H_nature                             4
# PREF_features_I_Sychro                           629
# PREF_features_J_collabspace                      713
# PREF_features_K_temp                             247
# PREF_features_L_clean                            247
# PREF_features_M_lockers                            0
# PREF_features_N_events                             0
# PREF_features_O_food                               0
# PREF_features_Q_kitchen                          470
# PREF_features_R_gym                                0
# PREF_features_S_relax                              0
# PREF_features_T_greenspace                         0
# PREF_CollabSpace_A_tech                            4
# PREF_CollabSpace_B_software                      331
# PREF_CollabSpace_C_CollabTools                     4
# PREF_CollabSpace_D_furniture                     246
# PREF_CollabSpace_E_seating                       246
# PREF_CollabSpace_F_naturallight                  246
# PREF_CollabSpace_G_acoustics                     331
# SATSF_CollabSpace_A_Tech                           4
# SATSF_CollabSpace_B_software                     331
# SATSF_CollabSpace_C_CollabTools                    4
# SATSF_CollabSpace_D_furniture                    246
# SATSF_CollabSpace_E_seating                      246
# SATSF_CollabSpace_F_naturallight                 246
# SATSF_CollabSpace_G_acoustics                    331
# SATSF_HomeOffice_A_Tech                          331
# SATSF_HomeOffice_B_software                      331
# SATSF_HomeOffice_C_CollabTools                   331
# SATSF_HomeOffice_D_furniture                     331
# SATSF_HomeOffice_E_seating                       331
# SATSF_HomeOffice_F_naturallight                  331
# SATSF_HomeOffice_G_acoustics                     331
# SATSF_office_A_community                         246
# SATSF_office_B_designexcellence                  328
# SATSF_office_C_pride                             246
# SATSF_office_D_expressme                         246
# SATSF_office_E_control                           246
# SATSF_office_F_wellbeing                         246
# SATSF_office_G_myfamily                          246
# SATSF_office_H_customers                         246
# SATSF_office_I_orgcullture                       246
# SATSF_office_J_knowledgeshare                    246
# SATSF_office_K_planet                            246
# SATSF_facilitate_Home_1A_focus                   331
# SATSF_facilitate_Home_1B_inpersoncollab          331
# SATSF_facilitate_Home_1C_virtualcollab           331
# SATSF_facilitate_Office_2A_focus                 247
# SATSF_facilitate_Office_2B_inpersoncollab        247
# SATSF_facilitate_Office_2C_virtualcollab         247
# SATSF_facilitate_HomeTech_3A_virtualcollab       331
# SATSF_facilitate_HomeTech_3B_inpersoncollab      331
# SATSF_facilitate_HomeTech_3C_virtualcollab       331
# SATSF_facilitate_OfficeTech_4A_virtualcollab     247
# SATSF_facilitate_OfficeTech_4B_inpersoncollab    247
# SATSF_facilitate_OfficeTech_4C_virtualcollab     247
# WP_Featr_office_A_community                      246
# WP_Featr_office_B_designexcellence               328
# WP_Featr_office_C_pride                          246
# WP_Featr_office_D_expressme                      246
# WP_Featr_office_E_control                        246
# WP_Featr_office_F_wellbeing                      246
# WP_Featr_office_G_myfamily                       246
# WP_Featr_office_H_customers                      246
# WP_Featr_office_I_oegculture                     246
# WP_Featr_office_J_knowledgeshare                 246
# WP_Featr_office_K_planet                         246
# Etc1_WLB_improved                                328
# Etc2_chooseWFH                                   328
# Etc3_no_workstation                              328
# Etc4_justlaptop                                  328
# Etc5_teamclose                                   328
# Etc6_connected                                   328
# Etc7_priorities                                  328
# Etc8_WFK_efffective                              328
# OBSV_PreC_WFH_Days_Wk                            248
# DEMO_Tenure_PreC_employee                        390
# PREF_WFK_rate_home                               248
# PostC_impact_shift_A_focus                       248
# PostC_impact_shift_B_productive                    6
# PostC_impact_shift_C_collab                        6
# PostC_impact_shift_F_colleagueaccess               6
# PostC_impact_shift_G_teammeetings                713
# PostC_impact_shift_H_social                      248
# PostC_impact_shift_I_managersconnect             328
# PostC_impact_shift_J_client                      248
# PostC_impact_shift_K_enjoy                       328
# DECSN_factors_A_noinpersonmtgs                   363
# DECSN_factors_B_healthwellness                   363
# DECSN_factors_C_WrkLifeSep                       328
# DECSN_factors_D_safety                           713
# OBSV_Now_WrkTimeA_Indiv_fract_vCollab              3
# OBSV_PreC_meetingsize0ffice_D_10plus             121
# PREF_space_B_inperson_collab                       4
# PREF_space_C_videoconf                             4
# PREF_space_D_impromptu                             4
# PREF_space_E_recharge                              4
# PREF_space_F_accessible                            4
# PREF_space_G_firstarrive                           4
# dtype: int64

# %%
orgs = data.DEMO_Org.unique()
datas = {}
for org in orgs:
    datas[org] = data[data.DEMO_Org == org]

# %%
gs  = {}

for org in orgs:
        gs[org] = data.columns[datas[org].isna().sum() != datas[org].shape[0]]

# %%
h = []
for org in orgs:
    h.append(gs[org])

# %%
common = list(set.intersection(*map(set,h)))

# %%
len(common)
# Out:
# 59

# %%
f = data[common]

# %%
f.to_excel("org134.xlsx")
