# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("WPA_DataCase_2024.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384 entries, 0 to 1383
# Columns: 185 entries, DEMO_Org to PREF_space_G_firstarrive
# dtypes: float64(90), object(95)
# memory usage: 2.0+ MB

# %%
data.describe()
# Out:
#        OBSV_PreC_Location_A_primryoffice  OBSV_PreC_Location_B_officeother  \
# count                         348.000000                        130.000000
# mean                            0.661310                          0.069346
# std                             0.314214                          0.156640
# min                             0.000000                          0.000000
# 25%                             0.400000                          0.000000
# 50%                             0.745000                          0.000000
# 75%                             1.000000                          0.050000
# max                             1.000000                          0.900000
#
#        OBSV_PreC_Location_C_client  OBSV_PreC_Location_D_WFH  \
# count                    98.000000                255.000000
# mean                      0.188837                  0.345922
# std                       0.251655                  0.273602
# min                       0.000000                  0.000000
# 25%                       0.000250                  0.100000
# 50%                       0.100000                  0.400000
# 75%                       0.250000                  0.500000
# max                       1.000000                  1.000000
#
#        OBSV_PreC_Location_E_publicspace  OBSV_PreC_Location_F_transit  \
# count                         67.000000                     88.000000
# mean                           0.026716                      0.087091
# std                            0.045938                      0.124213
# min                            0.000000                      0.000000
# 25%                            0.000000                      0.000000
# 50%                            0.000000                      0.050000
# 75%                            0.050000                      0.100000
# max                            0.200000                      0.800000
#
#        OBSV_PreC_Location_G_other  OBSV_Now_Interact_Work_within_org  \
# count                   80.000000                         240.000000
# mean                     0.133487                           0.528500
# std                      0.199152                           0.334573
# min                      0.000000                           0.000000
# 25%                      0.000000                           0.200000
# 50%                      0.050000                           0.500000
# 75%                      0.200000                           0.800000
# max                      0.950000                           1.000000
#
#        OBSV_PreC_meeting_A_inperson  OBSV_PreC_meeting_B_hyrbid  ...  \
# count                    691.000000                  672.000000  ...
# mean                       0.492740                    0.382021  ...
# std                        0.307883                    0.286653  ...
# min                        0.000000                    0.000000  ...
# 25%                        0.200000                    0.150000  ...
# 50%                        0.500000                    0.300000  ...
# 75%                        0.750000                    0.600000  ...
# max                        1.000000                    1.000000  ...
#
#        PostC_impact_shift_H_social  PostC_impact_shift_I_managersconnect  \
# count                  1136.000000                           1056.000000
# mean                      4.010123                              2.989110
# std                       1.151759                              1.253289
# min                       0.000000                              0.000000
# 25%                       4.000000                              2.500000
# 50%                       4.000000                              2.500000
# 75%                       5.000000                              4.000000
# max                       5.000000                              5.000000
#
#        PostC_impact_shift_J_client  PostC_impact_shift_K_enjoy  \
# count                   595.000000                 1056.000000
# mean                      2.903361                    2.366477
# std                       1.124186                    1.567645
# min                       0.000000                    0.000000
# 25%                       2.500000                    1.000000
# 50%                       2.500000                    2.500000
# 75%                       4.000000                    4.000000
# max                       5.000000                    5.000000
#
#        DECSN_factors_A_noinpersonmtgs  DECSN_factors_B_healthwellness  \
# count                      350.000000                       475.00000
# mean                         2.525714                         3.84000
# std                          1.343848                         1.22202
# min                          0.000000                         0.00000
# 25%                          2.500000                         2.50000
# 50%                          2.500000                         4.00000
# 75%                          4.000000                         5.00000
# max                          5.000000                         5.00000
#
#        DECSN_factors_C_WrkLifeSep  DECSN_factors_D_safety  \
# count                  512.000000              125.000000
# mean                     3.957031                3.100000
# std                      1.098438                1.014015
# min                      0.000000                2.500000
# 25%                      4.000000                2.500000
# 50%                      4.000000                2.500000
# 75%                      5.000000                4.000000
# max                      5.000000                5.000000
#
#        OBSV_Now_WrkTimeA_Indiv_fract_vCollab  \
# count                             842.000000
# mean                                0.675232
# std                                 0.218565
# min                                 0.000000
# 25%                                 0.500000
# 50%                                 0.750000
# 75%                                 0.850000
# max                                 1.000000
#
#        OBSV_PreC_meetingsize0ffice_D_10plus
# count                            183.000000
# mean                               0.133934
# std                                0.168702
# min                                0.000000
# 25%                                0.010000
# 50%                                0.100000
# 75%                                0.200000
# max                                1.000000
#
# [8 rows x 90 columns]

# %%
data.shape
# Out:
# (1384, 185)

# %%
data.head()
# Out:
#   DEMO_Org DEMO_meeting_remote   DEMO_Dept  OBSV_PreC_Location_A_primryoffice  \
# 0    Org 2                 NaN  Accounting                                0.8
# 1    Org 2                 NaN  Accounting                                0.6
# 2    Org 2                 NaN  Accounting                                0.6
# 3    Org 2                 NaN  Accounting                                0.5
# 4    Org 3                  No  Accounting                                NaN
#
#    OBSV_PreC_Location_B_officeother  OBSV_PreC_Location_C_client  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#    OBSV_PreC_Location_D_WFH  OBSV_PreC_Location_E_publicspace  \
# 0                       0.2                               NaN
# 1                       0.4                               NaN
# 2                       0.4                               NaN
# 3                       0.5                               NaN
# 4                       NaN                               NaN
#
#    OBSV_PreC_Location_F_transit  OBSV_PreC_Location_G_other  ...  \
# 0                           NaN                         NaN  ...
# 1                           NaN                         NaN  ...
# 2                           NaN                         NaN  ...
# 3                           NaN                         NaN  ...
# 4                           NaN                         NaN  ...
#
#    DECSN_factors_C_WrkLifeSep  DECSN_factors_D_safety  \
# 0                         4.0                     2.5
# 1                         5.0                     2.5
# 2                         NaN                     NaN
# 3                         4.0                     2.5
# 4                         4.0                     NaN
#
#    OBSV_Now_WrkTimeA_Indiv_fract_vCollab  \
# 0                                  0.600
# 1                                  0.700
# 2                                  0.750
# 3                                  0.700
# 4                                  0.875
#
#    OBSV_PreC_meetingsize0ffice_D_10plus  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                PREF_space_B_inperson_collab     PREF_space_C_videoconf  \
# 0  Enclosed room (meeting room, phone room)                        NaN
# 1                               Workstation                        NaN
# 2  Enclosed room (meeting room, phone room)                        NaN
# 3  Enclosed room (meeting room, phone room)                        NaN
# 4                 Elsewhere in the building  Elsewhere in the building
#
#       PREF_space_D_impromptu      PREF_space_E_recharge  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4  Elsewhere in the building  Elsewhere in the building
#
#    PREF_space_F_accessible  PREF_space_G_firstarrive
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4           Desk or office            Desk or office
#
# [5 rows x 185 columns]

# %%
data.DEMO_Dept.unique()
# Out:
# array(['Accounting', 'Operations and Support', 'Finance',
#        'Architect / Designer', 'Investments & BD',
#        'Construction Management & Site Development', 'Customer Support',
#        'Engineering', 'Environmental & Transport Specialist',
#        'Management', 'Human Resources', 'Information Systems / IT',
#        'Marketing', 'Product Development', 'Sales & Service',
#        'Workplace & Tech Services'], dtype=object)

# %%
data.isna().sum()
# Out:
# DEMO_Org                                0
# DEMO_meeting_remote                   914
# DEMO_Dept                               0
# OBSV_PreC_Location_A_primryoffice    1036
# OBSV_PreC_Location_B_officeother     1254
#                                      ...
# PREF_space_C_videoconf                134
# PREF_space_D_impromptu                134
# PREF_space_E_recharge                 675
# PREF_space_F_accessible               134
# PREF_space_G_firstarrive              675
# Length: 185, dtype: int64

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
pd.options.display.max_rows = 4000

# %%
data[data.DEMO_Org == 'Org 1'].isna().sum()
# Out:
# DEMO_Org                                          0
# DEMO_meeting_remote                               0
# DEMO_Dept                                         0
# OBSV_PreC_Location_A_primryoffice                10
# OBSV_PreC_Location_B_officeother                 37
# OBSV_PreC_Location_C_client                      22
# OBSV_PreC_Location_D_WFH                         27
# OBSV_PreC_Location_E_publicspace                 47
# OBSV_PreC_Location_F_transit                     34
# OBSV_PreC_Location_G_other                       60
# OBSV_Now_Interact_Work_within_org                85
# OBSV_PreC_meeting_A_inperson                      5
# OBSV_PreC_meeting_B_hyrbid                       12
# OBSV_PreC_meeting_C_remote                       23
# OBSV_PreC_interative_A_inperson                  85
# OBSV_PreC_interative_B_remote                    85
# OBSV_same_space_count_A_1                        85
# OBSV_same_space_count_B_2n3                      85
# OBSV_same_space_count_C_4n9                      85
# OBSV_same_space_count_D_10p                      85
# OBSV_PreC_meetingsize0ffice_A_1                  16
# OBSV_PreC_meetingsize0ffice_B_2n3                 4
# OBSV_PreC_meetingsize0ffice_C_4n9                17
# OBSV_PreC_wiOffice_A_desk                         0
# OBSV_PreC_wiOffice_B_otherdeck                    0
# OBSV_PreC_wiOffice_C_meetingrm                    0
# OBSV_PreC_wiOffice_D_lobby                        0
# OBSV_PreC_wiOffice_E_speicaltyarea                0
# OBSV_PreC_wiOffice_F_other                        0
# OBSV_PreC_space_A_InformalMtg                     0
# OBSV_PreC_space_B_FormalMtg                       0
# OBSV_PreC_5A_lost_layout                         41
# OBSV_PreC_5B_lost_looking                        16
# OBSV_PreC_5C_lost_perstech                       31
# OBSV_PreC_5D_lost_roomtech                       42
# OBSV_PreC_5E_lost_visitors                       28
# OBSV_PreC_5F_lost_noise                          20
# OBSV_PreC_5G_lost_comms                          26
# OBSV_PreC_5H_lost_ergo                           48
# OBSV_PreC_5I_lost_temp                           45
# OBSV_PreC_5J_lost_odor                           49
# OBSV_PreC_5K_lost_natlight                       49
# OBSV_PreC_5L_lost_indoorlight                    43
# PostC_impact_RankDifficult_A_MH                   5
# PostC_impact_RankDifficult_B_community            5
# PostC_impact_RankDifficult_C_Communication        5
# PostC_impact_RankDifficult_D_Tech                 5
# PostC_impact_RankDifficult_E_space                5
# PostC_impact_RankDifficult_F_Environment          5
# PostC_impact_shift_D_videoconf                   85
# PostC_impact_shift_E_innovate                    85
# DECSN_factors_E_commutelength                    85
# DECSN_factors_F_collabtools                      85
# DECSN_factors_G_concentrate                      85
# DECSN_factors_H_purpose                          85
# DECSN_factors_I_coworkerspresence                85
# DECSN_factors_J_teampresence                     85
# DECSN_factors_K_socialevents                     85
# DECSN_factors_L_community                        85
# DECSN_factors_M_metorship                        85
# DECSN_factors_N_neighorhood                      85
# DECSN_factors_O_food                             85
# DECSN_factors_P_family                           85
# DECSN_factors_Q_leadership                       85
# PREF_space_A_focusedWk                            3
# PREF_Envr_Focus_1A_activity                      19
# PREF_Envr_Focus_1B_closure                       13
# PREF_Envr_Focus_1C_remote                        16
# PREF_Envr_Focus_1D_color                         11
# PREF_Envr_Focus_1E_light                          5
# PREF_Envr_Focus_1F_formality                     14
# PREF_Envr_Focus_1H_energy                        10
# PREF_Envr_Collab_2A_activity                     11
# PREF_Envr_Collab_2B_closure                      12
# PREF_Envr_Collab_2C_remote                       10
# PREF_Envr_Collab_2D_color                        11
# PREF_Envr_Collab_2E_light                         6
# PREF_Envr_Collab_2F_formality                    11
# PREF_Envr_Collab_2H_energy                        9
# PREF_features_A_chair                             1
# PREF_features_B_proximitry                        1
# PREF_features_C_concentration                     0
# PREF_features_D_privacy                           1
# PREF_features_E_noise                             1
# PREF_features_F_daylight                          1
# PREF_features_G_light                             1
# PREF_features_H_nature                            1
# PREF_features_I_Sychro                            1
# PREF_features_J_collabspace                      85
# PREF_features_K_temp                              1
# PREF_features_L_clean                             1
# PREF_features_M_lockers                           0
# PREF_features_N_events                            0
# PREF_features_O_food                              0
# PREF_features_Q_kitchen                          85
# PREF_features_R_gym                               0
# PREF_features_S_relax                             0
# PREF_features_T_greenspace                        0
# PREF_CollabSpace_A_tech                           0
# PREF_CollabSpace_B_software                      85
# PREF_CollabSpace_C_CollabTools                    0
# PREF_CollabSpace_D_furniture                      0
# PREF_CollabSpace_E_seating                        0
# PREF_CollabSpace_F_naturallight                   0
# PREF_CollabSpace_G_acoustics                     85
# SATSF_CollabSpace_A_Tech                          0
# SATSF_CollabSpace_B_software                     85
# SATSF_CollabSpace_C_CollabTools                   0
# SATSF_CollabSpace_D_furniture                     0
# SATSF_CollabSpace_E_seating                       0
# SATSF_CollabSpace_F_naturallight                  0
# SATSF_CollabSpace_G_acoustics                    85
# SATSF_HomeOffice_A_Tech                          85
# SATSF_HomeOffice_B_software                      85
# SATSF_HomeOffice_C_CollabTools                   85
# SATSF_HomeOffice_D_furniture                     85
# SATSF_HomeOffice_E_seating                       85
# SATSF_HomeOffice_F_naturallight                  85
# SATSF_HomeOffice_G_acoustics                     85
# SATSF_office_A_community                          3
# SATSF_office_B_designexcellence                  85
# SATSF_office_C_pride                              3
# SATSF_office_D_expressme                          3
# SATSF_office_E_control                            3
# SATSF_office_F_wellbeing                          3
# SATSF_office_G_myfamily                           3
# SATSF_office_H_customers                          3
# SATSF_office_I_orgcullture                        3
# SATSF_office_J_knowledgeshare                     3
# SATSF_office_K_planet                             3
# SATSF_facilitate_Home_1A_focus                   85
# SATSF_facilitate_Home_1B_inpersoncollab          85
# SATSF_facilitate_Home_1C_virtualcollab           85
# SATSF_facilitate_Office_2A_focus                  1
# SATSF_facilitate_Office_2B_inpersoncollab         1
# SATSF_facilitate_Office_2C_virtualcollab          1
# SATSF_facilitate_HomeTech_3A_virtualcollab       85
# SATSF_facilitate_HomeTech_3B_inpersoncollab      85
# SATSF_facilitate_HomeTech_3C_virtualcollab       85
# SATSF_facilitate_OfficeTech_4A_virtualcollab      1
# SATSF_facilitate_OfficeTech_4B_inpersoncollab     1
# SATSF_facilitate_OfficeTech_4C_virtualcollab      1
# WP_Featr_office_A_community                       3
# WP_Featr_office_B_designexcellence               85
# WP_Featr_office_C_pride                           3
# WP_Featr_office_D_expressme                       3
# WP_Featr_office_E_control                         3
# WP_Featr_office_F_wellbeing                       3
# WP_Featr_office_G_myfamily                        3
# WP_Featr_office_H_customers                       3
# WP_Featr_office_I_oegculture                      3
# WP_Featr_office_J_knowledgeshare                  3
# WP_Featr_office_K_planet                          3
# Etc1_WLB_improved                                85
# Etc2_chooseWFH                                   85
# Etc3_no_workstation                              85
# Etc4_justlaptop                                  85
# Etc5_teamclose                                   85
# Etc6_connected                                   85
# Etc7_priorities                                  85
# Etc8_WFK_efffective                              85
# OBSV_PreC_WFH_Days_Wk                             5
# DEMO_Tenure_PreC_employee                         5
# PREF_WFK_rate_home                                5
# PostC_impact_shift_A_focus                        5
# PostC_impact_shift_B_productive                   5
# PostC_impact_shift_C_collab                       5
# PostC_impact_shift_F_colleagueaccess              5
# PostC_impact_shift_G_teammeetings                85
# PostC_impact_shift_H_social                       5
# PostC_impact_shift_I_managersconnect             85
# PostC_impact_shift_J_client                       5
# PostC_impact_shift_K_enjoy                       85
# DECSN_factors_A_noinpersonmtgs                   85
# DECSN_factors_B_healthwellness                   85
# DECSN_factors_C_WrkLifeSep                       85
# DECSN_factors_D_safety                           85
# OBSV_Now_WrkTimeA_Indiv_fract_vCollab             0
# OBSV_PreC_meetingsize0ffice_D_10plus             85
# PREF_space_B_inperson_collab                      3
# PREF_space_C_videoconf                            3
# PREF_space_D_impromptu                            3
# PREF_space_E_recharge                             3
# PREF_space_F_accessible                           3
# PREF_space_G_firstarrive                          3
# dtype: int64

# %%
data[data.DEMO_Org == 'Org 1'].shape
# Out:
# (85, 185)
